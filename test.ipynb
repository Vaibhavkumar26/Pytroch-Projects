# %%
from model import build_transformer
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python312\site-packages\torch\_subclasses\functional_tensor.py:368: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
print("Hi")
# Out:
# Hi

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import sys

project_path = "/content/drive/MyDrive"
sys.path.insert(0, project_path)

# %%
from model import build_transformer
